# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("nyc-rolling-sales.csv")

# %%
df.head(10000)
# Out:
#       Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0              4        1  ALPHABET CITY
# 1              5        1  ALPHABET CITY
# 2              6        1  ALPHABET CITY
# 3              7        1  ALPHABET CITY
# 4              8        1  ALPHABET CITY
# ...          ...      ...            ...
# 9995        9999        1    MURRAY HILL
# 9996       10000        1    MURRAY HILL
# 9997       10001        1    MURRAY HILL
# 9998       10002        1    MURRAY HILL
# 9999       10003        1    MURRAY HILL
#
#                           BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0     07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1     07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2     07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3     07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4     07 RENTALS - WALKUP APARTMENTS                                2A    404
# ...                                           ...                  ...    ...
# 9995  10 COOPS - ELEVATOR APARTMENTS                                 2    890
# 9996  10 COOPS - ELEVATOR APARTMENTS                                 2    890
# 9997  10 COOPS - ELEVATOR APARTMENTS                                 2    890
# 9998  10 COOPS - ELEVATOR APARTMENTS                                 2    890
# 9999  10 COOPS - ELEVATOR APARTMENTS                                 2    890
#
#       LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  ...  \
# 0       6                                  C2               153 AVENUE B  ...
# 1      26                                  C7      234 EAST 4TH   STREET  ...
# 2      39                                  C7      197 EAST 3RD   STREET  ...
# 3      21                                  C4        154 EAST 7TH STREET  ...
# 4      55                                  C2     301 EAST 10TH   STREET  ...
# ...   ...       ...                       ...                        ...  ...
# 9995    1                                  D4          7 PARK AVENUE, 91  ...
# 9996   20                                  D4   132 EAST 35TH STREET, 4B  ...
# 9997   20                                  D4  132 EAST 35TH STREET, 11D  ...
# 9998   20                                  D4  132 EAST 35TH STREET, 11C  ...
# 9999   20                                  D4   132 EAST 35TH STREET, 8E  ...
#
#      RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                    5                 0            5              1633
# 1                   28                 3           31              4616
# 2                   16                 1           17              2212
# 3                   10                 0           10              2272
# 4                    6                 0            6              2369
# ...                ...               ...          ...               ...
# 9995                 0                 0            0               -
# 9996                 0                 0            0               -
# 9997                 0                 0            0               -
# 9998                 0                 0            0               -
# 9999                 0                 0            0               -
#
#       GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0                  6440       1900                         2
# 1                 18690       1900                         2
# 2                  7803       1900                         2
# 3                  6794       1913                         2
# 4                  4615       1900                         2
# ...                 ...        ...                       ...
# 9995                -         1953                         2
# 9996                -         1969                         2
# 9997                -         1969                         2
# 9998                -         1969                         2
# 9999                -         1969                         2
#
#       BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                                 C2     6625000  2017-07-19 00:00:00
# 1                                 C7         -    2016-12-14 00:00:00
# 2                                 C7         -    2016-12-09 00:00:00
# 3                                 C4     3936272  2016-09-23 00:00:00
# 4                                 C2     8000000  2016-11-17 00:00:00
# ...                              ...         ...                  ...
# 9995                              D4      725000  2017-08-22 00:00:00
# 9996                              D4      882500  2017-01-11 00:00:00
# 9997                              D4      660000  2017-02-08 00:00:00
# 9998                              D4     1150000  2017-05-03 00:00:00
# 9999                              D4      999000  2017-06-08 00:00:00
#
# [10000 rows x 22 columns]

# %%
df_murr_hill =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "MURRAY HILL") & (df['SALE PRICE'] != ' -  ')]
a = df_murr_hill.astype(dtype=int).quantile(q=.5)

# %%
df_mid_west =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "MIDTOWN WEST") & (df['SALE PRICE'] != ' -  ')]
b = df_mid_west.astype(dtype=int).quantile(q=.5)

# %%
df_mid_east =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "MIDTOWN EAST") & (df['SALE PRICE'] != ' -  ')]
c = df_mid_east.astype(dtype=int).quantile(q=.5)

# %%
df_fin_dist =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "FINANCIAL") & (df['SALE PRICE'] != ' -  ')]
d = df_fin_dist.astype(dtype=int).quantile(q=.5)

# %%
df_flat_iron =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "FLATIRON") & (df['SALE PRICE'] != ' -  ')]
e = df_flat_iron.astype(dtype=int).quantile(q=.5)

# %%
df_upp_est =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "UPPER EAST SIDE (79-96)") & (df['SALE PRICE'] != ' -  ')]
f = df_upp_est.astype(dtype=int).quantile(q=.5)

# %%
listo1 = [b, c, d, e, f]
listo2 = ["MIDTOWN WEST", "MIDTOWN EAST", "FINANCIAL", "FLATIRON", "UPPER EAST SIDE (79-96)"]

# %%
fig = plt.figure(dpi=200)
ax = fig.add_axes([0,0,2,1])
ax.bar(listo2,listo1,color = ['green','blue','yellow','red','orange'])
plt.title('Median Housing Price of High MTA Traffic Neighborhoods (in Millions of $)')
plt.show()
plt.savefig("Neighborhood_House_Price.pdf")

# %%
df_harl_cent =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "HARLEM-CENTRAL") & (df['SALE PRICE'] != ' -  ')]
df_harl_cent.astype(dtype=int).quantile(q=.5)
# Out:
# 862500.0

# %%
df['SALE PRICE'][df['SALE PRICE'] != ' -  ']
# Out:
# 0         6625000
# 3         3936272
# 4         8000000
# 6         3192840
# 9        16232000
#            ...
# 84543      450000
# 84544      550000
# 84545      460000
# 84546    11693337
# 84547       69300
# Name: SALE PRICE, Length: 69987, dtype: object

# %%
df_garm_dist =  df["SALE PRICE"][(df["NEIGHBORHOOD"] == "HARLEM-CENTRAL") & (df['SALE PRICE'] != ' -  ')]
df_garm_dist.astype(dtype=int).quantile(q=.5)
# Out:
# 862500.0

# %%
pd.set_option('display.max_rows', 500)
df['NEIGHBORHOOD'].value_counts()
# Out:
# FLUSHING-NORTH               3068
# UPPER EAST SIDE (59-79)      1736
# UPPER EAST SIDE (79-96)      1590
# DOWNTOWN-FULTON MALL          276
# LITTLE NECK                   276
# MARINERS HARBOR               273
# BATH BEACH                    272
# WESTERLEIGH                   267
# DOWNTOWN-FULTON FERRY         265
# SCHUYLERVILLE/PELHAM BAY      264
# CONEY ISLAND                  263
# EAST ELMHURST                 257
# OLD MILL BASIN                256
# BOERUM HILL                   248
# BELLEROSE                     244
# MELROSE/CONCOURSE             244
# TOTTENVILLE                   243
# WILLOWBROOK                   237
# WAKEFIELD                     235
# FLATLANDS                     234
# MANHATTAN VALLEY              234
# SOUTH BEACH                   232
# BROWNSVILLE                   227
# FORT GREENE                   224
# FLORAL PARK                   223
# GOWANUS                       215
# NEW BRIGHTON                  215
# KINGSBRIDGE/JEROME PARK       210
# BRIARWOOD                     205
# ALPHABET CITY                 204
# BEDFORD PARK/NORWOOD          203
# PARK SLOPE SOUTH              202
# MIDTOWN CBD                   200
# ROSEBANK                      199
# ANNADALE                      198
# CAMBRIA HEIGHTS               198
# ARVERNE                       197
# BERGEN BEACH                  194
# BEECHHURST                    194
# CARROLL GARDENS               191
# CASTLE HILL/UNIONPORT         188
# ROSSVILLE                     183
# NEW DORP                      180
# WINDSOR TERRACE               180
# EAST VILLAGE                  178
# FLATBUSH-LEFFERTS GARDEN      170
# COUNTRY CLUB                  168
# GRANT CITY                    168
# KENSINGTON                    160
# DOWNTOWN-METROTECH            157
# JAMAICA ESTATES               154
# WASHINGTON HEIGHTS LOWER      151
# FRESH MEADOWS                 151
# PELHAM PARKWAY NORTH          145
# EAST TREMONT                  145
# HILLCREST                     144
# PRINCES BAY                   144
# SOUTHBRIDGE                   142
# WESTCHESTER                   142
# MANOR HEIGHTS                 142
# HARLEM-UPPER                  141
# CASTLETON CORNERS             140
# MOTT HAVEN/PORT MORRIS        140
# COBBLE HILL                   139
# PELHAM PARKWAY SOUTH          134
# HUGUENOT                      134
# MILL BASIN                    133
# WOODROW                       131
# KINGSBRIDGE HTS/UNIV HTS      130
# ROCKAWAY PARK                 129
# HIGHBRIDGE/MORRIS HEIGHTS     129
# HOLLISWOOD                    125
# GERRITSEN BEACH               123
# FASHION                       121
# INWOOD                        119
# STAPLETON                     118
# CLOVE LAKES                   117
# NEW DORP-BEACH                117
# CHINATOWN                     115
# BELLE HARBOR                  112
# JAMAICA HILLS                 109
# CONCORD                       108
# TRAVIS                        107
# NEW DORP-HEIGHTS              106
# WYCKOFF HEIGHTS               106
# GRASMERE                       97
# MANHATTAN BEACH                94
# CITY ISLAND                    91
# BELMONT                        89
# MOUNT HOPE/MOUNT EDEN          88
# DONGAN HILLS                   88
# RICHMONDTOWN                   88
# WOODLAWN                       85
# HAMMELS                        85
# COBBLE HILL-WEST               84
# RED HOOK                       83
# PELHAM GARDENS                 80
# FORDHAM                        78
# HUNTS POINT                    76
# GREAT KILLS-BAY TERRACE        75
# PORT IVORY                     73
# GRYMES HILL                    73
# MORNINGSIDE HEIGHTS            72
# SPRING CREEK                   70
# PLEASANT PLAINS                69
# BATHGATE                       68
# ROOSEVELT ISLAND               68
# SEAGATE                        67
# STAPLETON-CLIFTON              66
# CROTONA PARK                   65
# DONGAN HILLS-COLONY            65
# OAKWOOD-BEACH                  65
# HOLLIS HILLS                   64
# BUSH TERMINAL                  63
# ROSSVILLE-CHARLESTON           62
# SILVER LAKE                    62
# TODT HILL                      58
# TOMPKINSVILLE                  55
# UPPER EAST SIDE (96-110)       55
# NAVY YARD                      47
# FIELDSTON                      46
# ARROCHAR                       45
# BROAD CHANNEL                  44
# LITTLE ITALY                   41
# JAVITS CENTER                  41
# OAKWOOD                        40
# HARLEM-WEST                    38
# NEPONSIT                       34
# ARROCHAR-SHORE ACRES           33
# LIVINGSTON                     33
# NEW BRIGHTON-ST. GEORGE        29
# CONCORD-FOX HILLS              28
# JAMAICA BAY                    22
# EMERSON HILL                   21
# FLUSHING MEADOW PARK           16
# RICHMONDTOWN-LIGHTHS HILL      16
# ROSSVILLE-RICHMOND VALLEY      16
# BLOOMFIELD                      9
# AIRPORT LA GUARDIA              8
# ROSSVILLE-PORT MOBIL            6
# DONGAN HILLS-OLD TOWN           5
# CO-OP CITY                      5
# VAN CORTLANDT PARK              2
# FRESH KILLS                     2
# BRONX PARK                      1
# CITY ISLAND-PELHAM STRIP        1
# EAST RIVER                      1
# PELHAM BAY                      1
# Name: NEIGHBORHOOD, dtype: int64

# %%
salespricedf = df_garm_dist.to_frame()

# %%
salespricedf.reset_index(inplace=True)

# %%
salespricedf['SALE PRICE'].astype(dtype=int).describe()
# Out:
# count    1.320000e+02
# mean     2.908353e+06
# std      6.185908e+06
# min      1.000000e+01
# 25%      6.725000e+05
# 50%      1.060000e+06
# 75%      2.606877e+06
# max      5.700000e+07
# Name: SALE PRICE, dtype: float64

# %%
#int(df_garm_dist[i]) for i in df_garm_dist.index
listo = []
for i in range(len(df_garm_dist)):
    listo.append(int(df_garm_dist[i]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-a4ce42d3cf50> in <module>
#       2 listo = []
#       3 for i in range(len(df_garm_dist)):
# ----> 4     listo.append(int(df_garm_dist[i]))
#       5
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
df_east_village =  df[df["SALE PRICE"][df["NEIGHBORHOOD"] == "EAST VILLAGE"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-1b9e320110ea> in <module>
# ----> 1 df_east_village =  df[df["SALE PRICE"][df["NEIGHBORHOOD"] == "EAST VILLAGE"]]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['3000000', ' -  ', '6800000', '4000000', '13835000', '5292000', ' -  ',\n       ' -  ', ' -  ', ' -  ',\n       ...\n       '9150000', ' -  ', ' -  ', ' -  ', '250000', ' -  ', ' -  ', ' -  ',\n       ' -  ', ' -  '],\n      dtype='object', length=178)] are in the [columns]"

# %%
df_east_village
# Out:
# 1791     3000000
# 1792         -
# 1793     6800000
# 1794     4000000
# 1795    13835000
#           ...
# 1964         -
# 1965         -
# 1966         -
# 1967         -
# 1968         -
# Name: SALE PRICE, Length: 178, dtype: object

# %%
filter_east_village(df_east_village)
# Out:
# []
